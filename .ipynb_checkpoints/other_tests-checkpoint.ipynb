# %%
# Load functions defined in this package for class group computations
load("functions.sage")

# %%
sqrt(221+4)
# Out:
# 15

# %%
D=221;
g=wide_genus(D)
h=ZZ[(D+D^(1/2))/2].class_number()
print([g,h])
# Out:
# Not implemented currently. Previous implementation was incorrect.
# [None, 2]

# %%
factor(221)
# Out:
# 13 * 17

# %%
genus(221)
# Out:
# 2

# %%
negpell(D)
# Out:
# False

# %%
K=QQ[(D+D^(1/2))/2]
G=K.unit_group()

# %%
G
# Out:
# Unit group with structure C2 x Z of Number Field in a with defining polynomial x^2 - 221*x + 12155 with a = 117.9330343736593?

# %%
u=G.gens_values()[1]
uconj=u.trace()-u

# %%
u*uconj
# Out:
# 1

# %%
genus(-11^11)
# Out:
# 1

# %%
D=-11^11;
ZZ[(D+D^(1/2))/2].class_number()
# Out:
# 161051

# %%
divisors(D)
# Out:
# [1,
#  11,
#  121,
#  1331,
#  14641,
#  161051,
#  1771561,
#  19487171,
#  214358881,
#  2357947691,
#  25937424601,
#  285311670611]

# %%
genus(D)
# Out:
# 1

# %%
{1,2,3,1}
# Out:
# {1, 2, 3}

# %%
len({1,2,3,1})
# Out:
# 3

# %%
min(1,-2)
# Out:
# -2

# %%
genus_slow(5*13*17*101)
# Out:
# 8

# %%
for D in [1..200]:
    if discQ(D):
        print([D,genus(D),genus_slow(D)])
# Out:
# [5, 1, 1]
# [8, 1, 1]
# [12, 2, 2]
# [13, 1, 1]
# [17, 1, 1]
# [20, 1, 1]
# [21, 2, 2]
# [24, 2, 2]
# [28, 2, 2]
# [29, 1, 1]
# [32, 2, 2]
# [33, 2, 2]
# [37, 1, 1]
# [40, 2, 2]
# [41, 1, 1]
# [44, 2, 2]
# [45, 2, 2]
# [48, 2, 2]
# [52, 1, 1]
# [53, 1, 1]
# [56, 2, 2]
# [57, 2, 2]
# [60, 4, 4]
# [61, 1, 1]
# [65, 2, 2]
# [68, 1, 1]
# [69, 2, 2]
# [72, 2, 2]
# [73, 1, 1]
# [76, 2, 2]
# [77, 2, 2]
# [80, 2, 2]
# [84, 2, 2]
# [85, 2, 2]
# [88, 2, 2]
# [89, 1, 1]
# [92, 2, 2]
# [93, 2, 2]
# [96, 4, 4]
# [97, 1, 1]
# [101, 1, 1]
# [104, 2, 2]
# [105, 4, 4]
# [108, 2, 2]
# [109, 1, 1]
# [112, 2, 2]
# [113, 1, 1]
# [116, 1, 1]
# [117, 2, 2]
# [120, 4, 4]
# [124, 2, 2]
# [125, 1, 1]
# [128, 2, 2]
# [129, 2, 2]
# [132, 2, 2]
# [133, 2, 2]
# [136, 2, 2]
# [137, 1, 1]
# [140, 4, 4]
# [141, 2, 2]
# [145, 2, 2]
# [148, 1, 1]
# [149, 1, 1]
# [152, 2, 2]
# [153, 2, 2]
# [156, 4, 4]
# [157, 1, 1]
# [160, 4, 4]
# [161, 2, 2]
# [164, 1, 1]
# [165, 4, 4]
# [168, 4, 4]
# [172, 2, 2]
# [173, 1, 1]
# [176, 2, 2]
# [177, 2, 2]
# [180, 2, 2]
# [181, 1, 1]
# [184, 2, 2]
# [185, 2, 2]
# [188, 2, 2]
# [189, 2, 2]
# [192, 4, 4]
# [193, 1, 1]
# [197, 1, 1]
# [200, 2, 2]
